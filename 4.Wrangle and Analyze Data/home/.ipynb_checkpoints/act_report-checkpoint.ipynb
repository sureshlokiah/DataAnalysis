# %% [markdown]
# # Analysis and Insights Report - WeRateDogs  Twitter data
# .
# .
# ## Author : Suresh Lokiah

# %% [markdown]
# ## Scope:
#
# This document shares the analysis and insights gathered from  Wrangling the Twitter data - WeRateDogs.

# %% [markdown]
# ## Visualization
# Using the data gathered, assesed and clean the following visualizations were deveopled.
#
# 1. Popular Dog names (Bar Plot)
# 2. Popular Dog breed(Bar Plot)
# 3. Retweet Count vs Favorite Count (Scatter Plot)

# %% [markdown]
# ### 1. Popular Dog names (Bar Plot)

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
#
#
# The above chart shows popular (top 3) dog names as
# 1. Charlie
# 2. Lucy.
# 3. Oliver

# %% [markdown]
# ### 2. Popular Dog breed(Bar Plot)

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
#
# The above chart shows popular (top 3) dog breeds as
# 1. Golden Retriever
# 2. Labrador Retriever
# 3. Pembroke

# %% [markdown]
# ### 3. Retweet Count vs Favorite Count (Scatter Plot)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# The above scatter plot shows the relationship between favorite count and retweet count.

# %% [markdown]
# ## Summary
#
# The Visualizations leveraged the cleaned-up data from 3 datasources and shared valuable insights from the Twitter data.
