# %% [markdown]
# # Data Wrangling - Analysis and insights
# .
# .
# .
# ## Author : Suresh Lokiah

# %% [markdown]
# ## Scope:
# Perform Gather, Assess, Clean and visualization on data obtained from WeRateDogs Twitter archive that rates dogs on and has unique rating system.
#
# The data is gathered from 3 data sources
# 1. twitter-archive-enhanced - contains tweet data for 5000+ tweets. It has 'text'field of the tweet and dog "stage" fields  (i.e. doggo, floofer, pupper, and puppo)
#
# 2. Image Predcitions - Each image from the Tweet is processed using neural network to classify the dog breed using 3 predcitions (p1, p2, p3)
#
# 3. Tweet_json - downloaded the data that was gathered using Twitter API. This data has the retweet_count and favorite_count

# %% [markdown]
# ## Assessing Data
#
# Each dataset was systematically reviewed and, observations, quality and tidyness issues
# were documented at each step. Additionally, the step also makes guidance to "Next Step".
# So here is the format
#
# - Observation
#     - This section captures the observations made
#
# - Quality
#     - This captures the quality issues noted
#
# - Tidyness
#     - This captures the Tidyness issues
#
# - Next Step
#     - Guides to the next steps being performed
#
#
# The following Quality and Tidyness issues were observed after assessing the datasets
#
# #### Issues
#
# ##### Quality
# `twitter-archive-enhanced.csv`
# 1. **Incorrect datatype** -
#     1. **Number fields to Strings** - The following fields have a number datatype - tweet_id, in_reply_to_status_id, in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id. These must all be String as there is no numerical calculations needed on those.
#     2. **Object field must be datetime** - The timestamp, retweeted_status_timestamp must be datetime type
# 1. Column `tweet_id` must be a string
# 1. Column `in_reply_to_status_id` must be a string
# 1. Column `in_reply_to_user_id` must be a string
# 1. Fix column name Floofer as Floof
# 1. Fix values in column Floofer to floof
# 1. Create a column as dogtype and fill the value by parsing it from `text` field
# 1. Fix Non-name Dog names from `text` field.
# 1. Fix 'None' name from the text field
# 1. 84% of rows have unknown dog type
# 1. Replace string(None) to literal None
#
# `image-predictions.tsv`
#
# 1. `tweet_id` must be string
# 1. Fix Dog type
#
# `tweet-json.txt`
#
# 1. Fix `id` column and type
#
# ##### Tidyness
#
# 1. **Combine Table** - Looks like we can join the dataframes (df_twitter, df_image_predictions, df_ tweet_json ) using tweet_id
# 1. Drop the column img_num

# %% [markdown]
# ## Cleaning the data
# A cloned copy of each dataframe was made with suffix "_clean" and was used to clean the data.
#
# The following types of cleaning was performed on the data -
#
# `twitter-archive-enhanced`
# 1. Fixing the data types
# 2. Replace string value 'None' to  None
# 3. Fixing the Column Name
# 4. Fixing the Values in Column
# 5. Fixing the dog names
# 6. Fixing Dog Stage
#
# `image_predictions`
# 7. Fix Columns - tweet_id
# 8. Fix dog breed
#
# `tweet_json`
#
# 9. Fix column name - id
# 10. Fix column type - tweet_id
#
# And,
#
# 11. Combining the dataframes
# 12. Drop the img_num column
#
# The resulting clean data was archived into  'twitter_archive_master.csv' file for visualization.

# %% [markdown]
# ## Visualization
# Using the data gathered, assesed and clean the following visualizations were deveopled.
#
# 1. Popular Dog names (Bar Plot)
# 2. Popular Dog breed(Bar Plot)
# 3. Retweet Count vs Favorite Count (Scatter Plot)
#
# ![image.png](attachment:image.png)
#
#
# The above chart shows popular (top 3) dog names as
# 1. Charlie
# 2. Oliver
# 3. Lucy.
#
#
# ![image-2.png](attachment:image-2.png)
#
# The above chart shows popular (top 3) dog breeds as
# 1. Golden Retriever
# 2. Labrador Retriever
# 3. Pembroke
#
#
#
# ![image-3.png](attachment:image-3.png)
#
# The above scatter plot shows the relationship between favorite count and retweet count.

# %% [markdown]
# ## Summary
# This exercise to Assess, Clean and Visualize the data fulfils the scope and provided good learning opportunity that will come in handy in a realworld dataset.
